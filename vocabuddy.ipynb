# %% [markdown]
# <a href="https://colab.research.google.com/github/leolin8000-cloud/vocabuddy-group-1/blob/main/vocabuddy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi github and colab")
# Out:
# hi github and colab

# %%
vocab = {
    "repository": "倉庫",
    "invitation": "邀請",
    "collaborate": "合作",
}
print(vocab)
# Out:
# {'repository': '倉庫', 'invitation': '邀請', 'collaborate': '合作'}
